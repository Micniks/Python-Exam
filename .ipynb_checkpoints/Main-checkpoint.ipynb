# %%
import DnD_Dataset_Handler as dh
import pandas as pd

default_file_in_local = 'Datasets/CharacterDataset.tsv'
unmodifed_file_in_local = 'Datasets/Unmodified_Dataset.tsv'

# Read in the dataset
dataset_handler = dh.DND_Dataset_handler()
#dataset_handler = dh.DND_Dataset_handler(default_file_in_local)
dataset = dataset_handler.dataset
display(dataset)

    # Save datasets for later use, if internet is down
# dataset_handler.saveToFile()
# dh.DND_Dataset_handler(None, False).saveToFile('Unmodified_Dataset')
# Out:
#       Unnamed: 0    name        race    background                  date  \
# 0              0  9f3a61       Human     Charlatan  2018-07-27T23:53:51Z
# 1              1  9f3a61       Human        Custom  2018-07-27T17:07:02Z
# 2              2  7a2bfc       Kenku      Criminal  2018-05-27T20:14:52Z
# 3              3  aa8854    High Elf      Criminal  2018-08-04T15:45:17Z
# 4              4  26410c     Firbolg     Folk Hero  2018-07-26T03:31:17Z
# ...          ...     ...         ...           ...                   ...
# 1342        1342  eecfc2    Tiefling     Charlatan  2018-05-17T23:12:06Z
# 1343        1343  7ff7d2    Tiefling         Noble  2018-05-17T23:13:52Z
# 1344        1344  84085a       Human  Far Traveler  2018-05-16T19:50:43Z
# 1345        1345  c0a87f      Turtle          Sage  2018-05-18T17:01:58Z
# 1346        1346  73696e  Dragonborn       Soldier  2018-05-21T00:48:00Z
#
#                     class      justClass                             subclass  \
# 0               Warlock 1        Warlock                            The Fiend
# 1               Warlock 1        Warlock                            The Fiend
# 2               Warlock 3        Warlock                        The Celestial
# 3                Wizard 1         Wizard                                  NaN
# 4                Cleric 4         Cleric                      Trickery Domain
# ...                   ...            ...                                  ...
# 1342           Warlock 20        Warlock                         The Hexblade
# 1343           Paladin 20        Paladin                     Oath of Ancients
# 1344  Wizard 20|Cleric 10  Wizard|Cleric  School of Abjuration|Tempest Domain
# 1345             Druid 12          Druid                     Circle of spores
# 1346          Barbarian 3      Barbarian                Path of the Berserker
#
#       level             feats  ...  \
# 0         1             Lucky  ...
# 1         1             Lucky  ...
# 2         3               NaN  ...
# 3         1               NaN  ...
# 4         4  Inspiring Leader  ...
# ...     ...               ...  ...
# 1342     20   Heavily Armored  ...
# 1343     20       Tough|Lucky  ...
# 1344     30   Elemental Adept  ...
# 1345     12               NaN  ...
# 1346      3               NaN  ...
#
#                                                  skills  \
# 0     Sleight of Hand|Insight|Perception|Deception|I...
# 1                        Insight|Deception|Intimidation
# 2     Sleight of Hand|Stealth|Arcana|Religion|Deception
# 3     Stealth|Arcana|Investigation|Perception|Deception
# 4              History|Animal Handling|Insight|Survival
# ...                                                 ...
# 1342  Sleight of Hand|Investigation|Deception|Intimi...
# 1343          Athletics|History|Intimidation|Persuasion
# 1344                  Arcana|History|Insight|Perception
# 1345     Arcana|History|Nature|Animal Handling|Survival
# 1346         Athletics|Perception|Survival|Intimidation
#
#                                                 weapons  \
# 0     Crossbow, light|Eldritch Blast PHB237|Burning ...
# 1     Crossbow, light|Eldritch Blast PHB237|Burning ...
# 2                                Crossbow, Light|Dagger
# 3                                          Quarterstaff
# 4                                  Mace|Crossbow, light
# ...                                                 ...
# 1342                                    Dagger|Greataxe
# 1343                         Javelin|Greataxe|Longsword
# 1344                                       Quarterstaff
# 1345                                       Quarterstaff
# 1346                                   Dagger|Longsword
#
#                                                  spells       day  \
# 0     Eldritch blast*0|Minor illusion*0|Hex*1|Burnin...  07 27 18
# 1     Eldritch blast*0|Minor illusion*0|Hex*1|Burnin...  07 27 18
# 2     Light*0|Sacred Flame*0|Eldritch Blast*0|Agoniz...  05 27 18
# 3                                                   NaN  08 04 18
# 4     Charm Person*1|Disguise Self*1|Mirror Image*2|...  07 25 18
# ...                                                 ...       ...
# 1342                                                NaN  05 17 18
# 1343  Ensnaring Strike*1|Speak with Animals*1|Moonbe...  05 17 18
# 1344  Fog Cloud*1|Thunderwave*1|Gust of Wind*2|Shatt...  05 16 18
# 1345  Chill Touch*0|+Gentle Repose*2|+Ray Of Enfeebl...  05 18 18
# 1346                                                NaN  05 20 18
#
#       processedAlignment  good  lawful  processedRace  \
# 0                     CN     N       C          Human
# 1                     CN     N       C          Human
# 2                    NaN   NaN     NaN          Kenku
# 3                    NaN   NaN     NaN            Elf
# 4                    NaN   NaN     NaN        Firbolg
# ...                  ...   ...     ...            ...
# 1342                 NaN   NaN     NaN       Tiefling
# 1343                 NaN   NaN     NaN       Tiefling
# 1344                  CG     G       C          Human
# 1345                  CN     N       C         Turtle
# 1346                 NaN   NaN     NaN     Dragonborn
#
#                                         processedSpells  \
# 0     Eldritch Blast*0|Minor Illusion*0|Hex*1|Burnin...
# 1     Eldritch Blast*0|Minor Illusion*0|Hex*1|Burnin...
# 2     Light*0|Sacred Flame*0|Eldritch Blast*0|Eldrit...
# 3                                                   NaN
# 4     Charm Person*1|Disguise Self*1|Mirror Image*2|...
# ...                                                 ...
# 1342                                                NaN
# 1343  Ensnaring Strike*1|Speak with Animals*1|Moonbe...
# 1344  Fog Cloud*1|Thunderwave*1|Gust of Wind*2|Shatt...
# 1345  Chill Touch*0|Gentle Repose*2|Ray of Enfeeblem...
# 1346                                                NaN
#
#                 processedWeapons
# 0         Crossbow, Light|Dagger
# 1         Crossbow, Light|Dagger
# 2         Crossbow, Light|Dagger
# 3                   Quarterstaff
# 4           Mace|Crossbow, Light
# ...                          ...
# 1342             Dagger|Greataxe
# 1343  Javelin|Greataxe|Longsword
# 1344                Quarterstaff
# 1345                Quarterstaff
# 1346            Dagger|Longsword
#
# [1347 rows x 29 columns]

# %%
import MashineLearningTest as mlt

# Test funcionality of a single prediction, for a list of ability scores, and see the given result
test = mlt.DNDClassPredictor(dataset)
print(test.dataset.shape)
result = test.predict_class_from_ability_scores([18,12,14,10,8,14])
print(result)

# %%
import Webscraber as ws
#Webscrabing: Make a method that takes a string, and searches https://roll20.net/compendium/dnd5e/ for that string, 
#and returns the resulting text. Add Selenium, by using the searchbar, and selecting the right object from list.

get_text = ws.Webscraber.webcrawling_using_selenium_soup("Fireball")

# %%
import ClassRaceSynergy as crs

crs_class = crs.ClassRaceSynergy(dataset)

#df = crs_class.get_class_picked_by_race_percentage_table()
#df = crs_class.get_count_table()
df = crs_class.get_percentage_table()

display(df)
