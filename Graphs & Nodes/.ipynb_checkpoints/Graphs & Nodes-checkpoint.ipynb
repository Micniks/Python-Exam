# %% [markdown]
# Graphs & Nodes:
# Show synergy between either feats, classes, or other, where the node-size is relative to the amount of the class, and the edges
# thickness relative to the amount that have both instances.

# %%
import networkx as nx
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

DnDChars = '../charTable.tsv'
double_classes = pd.read_csv(DnDChars, sep='\t')

double_class_list = [c for c in double_classes['justClass'] if '|' in c]
display(double_class_list)
 
G = nx.Graph()

edges = [tuple(e) for e in double_classes][1:]

for multiclass in double_class_list:
    G.add_nodes_from(multiclass)
    #G.add_edges_from(multiclass)
#G.add_edges_from(edges)
print(nx.info(G))
nx.draw_circular(G, with_labels=True)
# Out:
# ['Barbarian|Fighter|Rogue|Wizard|Bard|Paladin|Warlock',
#  'Fighter|Barbarian',
#  'Fighter|Bard',
#  'Paladin|Sorcerer',
#  'Cleric|Wizard',
#  'Monk|Druid',
#  'Warlock|Bard',
#  'Paladin|Sorcerer',
#  'Fighter|Cleric',
#  'Ranger|Rogue',
#  'Fighter|Warlock',
#  'Barbarian|Fighter|Rogue|Wizard|Bard|Paladin|Warlock',
#  'Fighter|Cleric',
#  'Fighter|Barbarian',
#  'Fighter|Barbarian',
#  'Ranger|Rogue',
#  'Barbarian|Druid',
#  'Wizard|Fighter',
#  'Revised Ranger|Rogue',
#  'Wizard|Fighter',
#  'Monk|Druid',
#  'Paladin|Bard|Warlock',
#  'Wizard|Fighter',
#  'Paladin|Wizard',
#  'Barbarian|Bard',
#  'Fighter|Rogue',
#  'Fighter|Cleric',
#  'Bard|Warlock',
#  'Sorcerer|Cleric',
#  'Fighter|Barbarian',
#  'Rogue|Fighter',
#  'Bard|Warlock',
#  'Ranger|Warlock',
#  'Rogue|Warlock',
#  'Warlock|Bard',
#  'Sorcerer|Warlock',
#  'Fighter|Barbarian',
#  'Wizard|Fighter',
#  'Fighter|Barbarian',
#  'Rogue|Revised Ranger',
#  'Rogue|Revised Ranger',
#  'Fighter|Cleric',
#  'Barbarian|Druid',
#  'Fighter|Cleric',
#  'Fighter|Rogue',
#  'Fighter|Rogue',
#  'Fighter|Rogue',
#  'Barbarian|Monk|Paladin|Fighter',
#  'Cleric|Wizard',
#  'Barbarian|Druid',
#  'Rogue|Fighter',
#  'Rogue|Fighter',
#  'Rogue|Fighter',
#  'Fighter|Barbarian',
#  'Sorcerer|Cleric',
#  'Sorcerer|Cleric',
#  'Rogue|Fighter',
#  'Barbarian|Fighter|Rogue|Wizard|Bard|Paladin|Warlock',
#  'Fighter|Rogue',
#  'Barbarian|Bard|Monk',
#  'Fighter|Barbarian',
#  'Monk|Druid',
#  'Fighter|Barbarian',
#  'Bard|Warlock',
#  'Cleric|Bard',
#  'Fighter|Warlock',
#  'Rogue|Cleric|Bard',
#  'Warlock|Sorcerer',
#  'Barbarian|Monk',
#  'Barbarian|Monk',
#  'Fighter|Monk',
#  'Sorcerer|Monk',
#  'Rogue|Ranger',
#  'Artificer|Rogue',
#  'Paladin|Sorcerer',
#  'Fighter|Warlock',
#  'Rogue|Fighter',
#  'Ranger|Rogue',
#  'Rogue|Wizard',
#  'Rogue|Cleric|Bard',
#  'Wizard|Fighter',
#  'Ranger|Rogue',
#  'Ranger|Rogue',
#  'Ranger|Rogue',
#  'Ranger|Rogue',
#  'Fighter|Cleric',
#  'Fighter|Monk',
#  'Paladin|Wizard',
#  'Fighter|Rogue',
#  'Fighter|Warlock',
#  'Barbarian|Monk',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Ranger|Rogue',
#  'Bard|Warlock',
#  'Bard|Warlock',
#  'Barbarian|Fighter',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Barbarian|Fighter',
#  'Cleric|Rogue',
#  'Paladin|Sorcerer',
#  'Fighter|Wizard',
#  'Wizard|Fighter',
#  'Wizard|Fighter',
#  'Fighter|Rogue',
#  'Fighter|Mystic',
#  'Rogue|Cleric|Ranger',
#  'Druid|Monk',
#  'Sorcerer|Warlock',
#  'Fighter|Monk',
#  'Fighter|Cleric',
#  'Bard|Warlock',
#  'Bard|Fighter',
#  'Druid|Rogue',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Ranger|Rogue',
#  'Barbarian|Bard',
#  'Monk|Cleric',
#  'Rogue|Ranger|Bard',
#  'Fighter|Cleric',
#  'Ranger|Rogue',
#  'Wizard|Warlock',
#  'Bard|Rogue|Fighter',
#  'Paladin|Wizard',
#  'Bard|Fighter|Rogue',
#  'Sorcerer|Cleric',
#  'Sorcerer|Cleric',
#  'Fighter|Warlock',
#  'Fighter|Rogue',
#  'Paladin|Warlock',
#  'Wizard|Fighter',
#  'Fighter|Barbarian',
#  'Fighter|Barbarian',
#  'Fighter|Barbarian',
#  'Rogue|Revised Ranger',
#  'Rogue|Revised Ranger',
#  'Monk|Barbarian',
#  'Monk|Barbarian',
#  'Monk|Barbarian',
#  'Barbarian|Bard',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Rogue|Fighter',
#  'Sorcerer|Warlock',
#  'Sorcerer|Warlock',
#  'Druid|Monk',
#  'Barbarian|Bard',
#  'Fighter|Cleric',
#  'Wizard|Warlock',
#  'Barbarian|Fighter',
#  'Monk|Wizard',
#  'Paladin|Sorcerer',
#  'Bard|Warlock',
#  'Barbarian|Druid',
#  'Paladin|Sorcerer',
#  'Druid|Bard',
#  'Warlock|Sorcerer',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Monk|Rogue',
#  'Sorcerer|Cleric',
#  'Sorcerer|Cleric',
#  'Revised Ranger|Wizard',
#  'Paladin|Barbarian',
#  'Fighter|Cleric',
#  'Monk|Druid',
#  'Revised Ranger|Wizard',
#  'Ranger|Warlock',
#  'Fighter|Cleric',
#  'Fighter|Warlock',
#  'Rogue|Cleric',
#  'Druid|Monk',
#  'Rogue|Warlock',
#  'Rogue|Warlock',
#  'Sorcerer|Fighter|Barbarian',
#  'Rogue|Wizard',
#  'Fighter|Warlock|Sorcerer',
#  'Wizard|Fighter',
#  'Fighter|Cleric',
#  'Fighter|Cleric',
#  'Paladin|Warlock',
#  'Monk|Druid',
#  'Druid|Barbarian',
#  'Druid|Barbarian',
#  'Fighter|Barbarian',
#  'Fighter|Barbarian',
#  'Wizard|Fighter',
#  'Barbarian|Ranger',
#  'Barbarian|Ranger',
#  'Fighter|Wizard',
#  'Fighter|Wizard',
#  'Rogue|Monk|Warlock',
#  'Fighter|Revised Ranger',
#  'Fighter|Revised Ranger',
#  'Sorcerer|Monk',
#  'Fighter|Cleric',
#  'Fighter|Barbarian',
#  'Wizard|Cleric|Druid',
#  'Fighter|Warlock',
#  'Fighter|Bard',
#  'Rogue|Cleric',
#  'Paladin|Sorcerer',
#  'Fighter|Cleric',
#  'Wizard|Cleric']
# Name:
# Type: Graph
# Number of nodes: 32
# Number of edges: 0
# Average degree:   0.0000
