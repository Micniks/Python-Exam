# %% [markdown]
# Graphs & Nodes:
# Show synergy between either feats, classes, or other, where the node-size is relative to the amount of the class, and the edges
# thickness relative to the amount that have both instances.

# %%
import networkx as nx
import pandas as pd
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.model_selection import train_test_split
#import re

   # getting all the classes from the data
DnDChars = '../charTable.tsv'
character_data = pd.read_csv(DnDChars, sep='\t')
class_data = character_data[['justClass']]

   # dropping duplicates and getting all unique classes
drop_class_duplicates = class_data.drop_duplicates()
unique_classes = [c for c in drop_class_duplicates['justClass'] if "|" not in c]
unique_classes.sort()

   # getting all characters that have two or more classes
multiple_classes = [c for c in character_data['justClass'] if "|" in c]


   # separating all the classes by splitting strings at "|" and adding to new list
separated_classes = []
for i in multiple_classes:
    row = i.split("|")
    for r in row:
        separated_classes.append(r)

   # finding every class occurrence and adding to dictionary with "class" as key and "amount" as value
class_occurrences = {}
for occ in separated_classes:
    if occ in class_occurrences:
        class_occurrences[occ] +=1
    else:
        class_occurrences[occ] =1
    
    
   # finding all connected classes by separating each connected string and putting them together as dual then adding to new list
separated_edges = []
row = []
for q in multiple_classes:
    row = q.split("|")
    for idx_one in range(len(row)):
        for idx_two in range(idx_one+1,len(row)):
            separated_edges.append((row[idx_one], row[idx_two]))

   # iterating over connected classes (edges) in the new list and adding them to new dictionary
   # with "class connection" as key and "amount" as value
edge_occurrences = {}
for edge in separated_edges:
    if edge in edge_occurrences:
        edge_occurrences[edge] +=1
    else:
        edge_occurrences[edge] =1
        
   # displaying the nodes and edges (single class occurrence and class connection occurence)
display(class_occurrences)    
display(edge_occurrences)


   # creating the graph
#G = nx.Graph()

   # creating node sizes based on node occurrence and adding to graph
#nodes = class_occurrences.values()
#node_sizes = []
#for c in nodes:
    #node_size = 10 * c
    #node_sizes.append(node_size)

#G.add_nodes_from(class_occurrences.keys())
#pos=nx.circular_layout(G) 


   # defining edge size by how many occurrences they have and adding them to graph
#edges = edge_occurrences.keys()
#edge_sizes = []
#for e in edges:
    #value = edge_occurrences[e]
    #edge_size = 0.2 * value
    #edge_sizes.append(edge_size)

#G.add_edges_from(edges, weight=edge_sizes)


   # printing graph info
print(nx.info(G))


#import matplotlib.pyplot as pl
    
#nx.draw_circular(G, node_size = node_sizes, width = edge_sizes,
                 #node_color = "lime", edge_color = "red",
                 #font_size = 12, with_labels=True)
# Out:
# {'Barbarian': 43,
#  'Fighter': 115,
#  'Rogue': 52,
#  'Wizard': 30,
#  'Bard': 28,
#  'Paladin': 18,
#  'Warlock': 37,
#  'Sorcerer': 24,
#  'Cleric': 64,
#  'Monk': 25,
#  'Druid': 17,
#  'Ranger': 17,
#  'Revised Ranger': 9,
#  'Artificer': 1,
#  'Mystic': 1}
# {('Barbarian', 'Fighter'): 7,
#  ('Barbarian', 'Rogue'): 3,
#  ('Barbarian', 'Wizard'): 3,
#  ('Barbarian', 'Bard'): 8,
#  ('Barbarian', 'Paladin'): 4,
#  ('Barbarian', 'Warlock'): 3,
#  ('Fighter', 'Rogue'): 12,
#  ('Fighter', 'Wizard'): 6,
#  ('Fighter', 'Bard'): 5,
#  ('Fighter', 'Paladin'): 3,
#  ('Fighter', 'Warlock'): 11,
#  ('Rogue', 'Wizard'): 5,
#  ('Rogue', 'Bard'): 6,
#  ('Rogue', 'Paladin'): 3,
#  ('Rogue', 'Warlock'): 7,
#  ('Wizard', 'Bard'): 3,
#  ('Wizard', 'Paladin'): 3,
#  ('Wizard', 'Warlock'): 5,
#  ('Bard', 'Paladin'): 3,
#  ('Bard', 'Warlock'): 11,
#  ('Paladin', 'Warlock'): 6,
#  ('Fighter', 'Barbarian'): 16,
#  ('Paladin', 'Sorcerer'): 7,
#  ('Cleric', 'Wizard'): 2,
#  ('Monk', 'Druid'): 5,
#  ('Warlock', 'Bard'): 2,
#  ('Fighter', 'Cleric'): 45,
#  ('Ranger', 'Rogue'): 10,
#  ('Barbarian', 'Druid'): 4,
#  ('Wizard', 'Fighter'): 10,
#  ('Revised Ranger', 'Rogue'): 1,
#  ('Paladin', 'Bard'): 1,
#  ('Paladin', 'Wizard'): 3,
#  ('Sorcerer', 'Cleric'): 7,
#  ('Rogue', 'Fighter'): 8,
#  ('Ranger', 'Warlock'): 2,
#  ('Sorcerer', 'Warlock'): 4,
#  ('Rogue', 'Revised Ranger'): 4,
#  ('Barbarian', 'Monk'): 5,
#  ('Monk', 'Paladin'): 1,
#  ('Monk', 'Fighter'): 1,
#  ('Paladin', 'Fighter'): 1,
#  ('Bard', 'Monk'): 1,
#  ('Cleric', 'Bard'): 3,
#  ('Rogue', 'Cleric'): 5,
#  ('Warlock', 'Sorcerer'): 3,
#  ('Fighter', 'Monk'): 3,
#  ('Sorcerer', 'Monk'): 2,
#  ('Rogue', 'Ranger'): 3,
#  ('Artificer', 'Rogue'): 1,
#  ('Cleric', 'Rogue'): 1,
#  ('Fighter', 'Mystic'): 1,
#  ('Cleric', 'Ranger'): 1,
#  ('Druid', 'Monk'): 3,
#  ('Bard', 'Fighter'): 3,
#  ('Druid', 'Rogue'): 1,
#  ('Monk', 'Cleric'): 1,
#  ('Ranger', 'Bard'): 1,
#  ('Bard', 'Rogue'): 2,
#  ('Monk', 'Barbarian'): 3,
#  ('Monk', 'Wizard'): 1,
#  ('Druid', 'Bard'): 1,
#  ('Monk', 'Rogue'): 1,
#  ('Revised Ranger', 'Wizard'): 2,
#  ('Paladin', 'Barbarian'): 1,
#  ('Sorcerer', 'Fighter'): 1,
#  ('Sorcerer', 'Barbarian'): 1,
#  ('Fighter', 'Sorcerer'): 1,
#  ('Druid', 'Barbarian'): 2,
#  ('Barbarian', 'Ranger'): 2,
#  ('Rogue', 'Monk'): 1,
#  ('Monk', 'Warlock'): 1,
#  ('Fighter', 'Revised Ranger'): 2,
#  ('Wizard', 'Cleric'): 2,
#  ('Wizard', 'Druid'): 1,
#  ('Cleric', 'Druid'): 1}
# Name:
# Type: Graph
# Number of nodes: 15
# Number of edges: 55
# Average degree:   7.3333

# %%
import matplotlib.pyplot as pl

G = nx.Graph()

   # creating node sizes based on node occurrence and adding to graph
nodes = class_occurrences.values()
node_sizes = []
for c in nodes:
    node_size = 10 * c
    node_sizes.append(node_size)

G.add_nodes_from(class_occurrences.keys())
 
pos=nx.circular_layout(G) 
nx.draw_networkx_nodes(G, pos, node_color='lime', node_size = node_sizes)
 
    #3. If you want, add labels to the nodes
labels = {}
node_list = []
node_list = nodes = class_occurrences.keys()
for node_name in node_list:
    labels[str(node_name)] =str(node_name)
nx.draw_networkx_labels(G, pos, labels, font_size=8)


edges = edge_occurrences.keys()
edge_sizes = []
for e in edges:
    value = edge_occurrences[e]
    edge_size = 0.2 * value
    edge_sizes.append(edge_size)
    G.add_edge(*e, weight=edge_size)

all_weights = []
for (node1,node2,data) in G.edges(data=True):
        all_weights.append(data['weight']) #we'll use this when determining edge thickness
    
unique_weights = list(set(all_weights))

for weight in unique_weights:
        #4 d. Form a filtered list with just the weight you want to draw
        weighted_edges = [(node1,node2) for (node1,node2,edge_attr) in G.edges(data=True) if edge_attr['weight']==weight]
        #4 e. I think multiplying by [num_nodes/sum(all_weights)] makes the graphs edges look cleaner
        width = weight*25.0/sum(all_weights)
        nx.draw_networkx_edges(G, pos, node_size = node_sizes, edgelist=weighted_edges, width=width, 
                              node_color = "lime", edge_color = "red", font_size = 12, with_labels=True)
