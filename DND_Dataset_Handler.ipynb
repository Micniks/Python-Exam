# %%
import pandas as pd

default_link = 'https://raw.githubusercontent.com/oganm/dndstats/master/docs/charTable.tsv'
default_fileName = 'CharacterDataset.tsv'
official_dnd_classes = ['Artificer', 'Barbarian', 'Bard', 'Blood hunter', 'Cleric', 'Druid', 'Fighter', 'Monk', 'Paladin', 'Ranger', 'Rogue', 'Sorcerer', 'Warlock', 'Wizard']
official_dnd_races = ['Dragonborn', 'Dwarf', 'Elf', 'Gnome', 'Half-Elf', 'Halfling', 'Half-Orc', 'Human', 'Tiefling', 'Aasimar', 'Bugbear', 'Firbolg', 'Goblin', 'Hobgoblin', 'Kenku', 'Kobold', 'Lizardfolk', 'Orc', 'Tabaxi','Triton', 'Changeling', 'Kalashtar', 'Shifter', 'Warforged']

class DND_Dataset_handler:
    def __init__(self, link = default_link):
        self.dataset = self.pull(link)
        
    def pull(self, link):
        if link is None:
            dataset = pd.read_csv(default_link, sep='\t')
        else:
            dataset = pd.read_csv(link, sep='\t')
        return dataset
    
    def clean_dataset(self):
        
        # Remove characters with missing vital values
        self.dataset.dropna(subset=['race', 'level', 'justClass'], inplace=True)

        
        # Remove characters with a total level over 20 and below 1
        indexes_to_remove = self.dataset[self.dataset['level'] > 20].index
        self.dataset.drop(indexes_to_remove, inplace=True)
        indexes_to_remove = self.dataset[self.dataset['level'] < 1].index
        self.dataset.drop(indexes_to_remove, inplace=True)
        
        
        # Remove all characters with a non-official class choice
        indexes_to_remove = []
        all_index = self.dataset[self.dataset['level'] > 0].index
        for idx in all_index:
            classes = self.dataset['justClass'][idx]
            class_list = classes.split("|")
            for c in class_list:
                if c.capitalize() not in official_dnd_classes:
                    indexes_to_remove.append(idx)
        self.dataset.drop(indexes_to_remove, inplace=True)
        
        
        # Remove all characters with a non-official race choice
        indexes_to_remove = []
        all_index = self.dataset[self.dataset['level'] > 0].index
        for idx in all_index:
            full_race = self.dataset['race'][idx]
            race = full_race.split()[len(full_race.split())-1]
            self.dataset.loc[idx, ('race')] = race
            if race.capitalize() not in official_dnd_races:
                indexes_to_remove.append(idx)
        self.dataset.drop(indexes_to_remove, inplace=True)
        
        
        # Remove dublicate characters, keeping the last one
        self.dataset.drop_duplicates(subset='name', keep='last', inplace=True)
        
    def getSpecificCharacters(self, category, value):
        if category in ['race', 'name', 'justClass', 'class']:
            return self.dataset.loc[test.dataset[category].str.contains(value)]
        else:
            return self.dataset.loc[test.dataset[category] == value]
        
    def saveToFile(self, fileName = default_fileName):
        self.dataset.to_csv(fileName, sep = '\t')

# %%
test = DND_Dataset_handler()
display(test.dataset.shape)
test.clean_dataset()
display(test.dataset.shape)
#display(test.dataset)
#display(test.dataset.loc[test.dataset['race'].str.contains("Tiefling")])

result = test.getSpecificCharacters('justClass', 'Wizard')
display(result)
test.saveToFile()
# Out:
# (1347, 28)
# (638, 28)
#         name        race           background                  date  \
# 3     aa8854         Elf             Criminal  2018-08-04T15:45:17Z
# 122   0d8e98      Goblin                 Sage  2018-08-05T21:28:41Z
# 148   c22653         Elf               Urchin  2018-06-10T16:24:10Z
# 154   53f025    Tiefling              Soldier  2018-09-08T22:53:15Z
# 193   138968       Human                 Sage  2018-06-02T05:50:04Z
# 292   f64631       Human                Noble  2018-06-16T20:30:43Z
# 340   01678d       Gnome                 Sage  2018-06-16T11:07:31Z
# 361   c14234      Goblin         Far Traveler  2018-06-22T22:26:15Z
# 388   148dc9       Human   Cloistered Scholar  2018-08-30T15:16:56Z
# 394   04be37         Elf               Sailor  2018-06-27T15:26:47Z
# 415   e9a755         Elf        Guild Artisan  2018-07-09T16:23:02Z
# 419   89dbe6       Human            Folk Hero  2018-06-28T23:07:45Z
# 432   cb1021         Elf         Far Traveler  2018-07-27T01:36:48Z
# 479   301db0       Gnome            Charlatan  2018-06-15T00:21:44Z
# 529   f386ae       Gnome   Cloistered Scholar  2018-06-08T21:46:21Z
# 539   86c4c1         Elf                 Sage  2018-08-17T11:42:46Z
# 548   a12c42      Goblin              Acolyte  2018-05-26T14:45:06Z
# 552   f109bf       Human                Noble  2018-05-27T09:57:15Z
# 560   56b2db       Gnome               Hermit  2018-06-25T03:43:18Z
# 580   9dc6a4       Dwarf                 Sage  2018-09-04T22:03:37Z
# 616   395b9a       Gnome                 Sage  2018-07-30T02:53:31Z
# 627   849c74       Gnome            Inheritor  2018-05-26T03:39:15Z
# 631   89e62b         Elf                 Sage  2018-05-26T22:18:59Z
# 633   3de95d      Kobold   Cloistered Scholar  2018-06-16T01:54:08Z
# 640   af45bc         Elf  Urban Bounty Hunter  2018-07-22T17:57:26Z
# 652   f11604       Human                Noble  2018-06-24T12:59:48Z
# 657   a68963       Gnome         Clan Crafter  2018-08-12T17:36:09Z
# 663   12d62b    Tiefling               Urchin  2018-07-26T06:47:31Z
# 664   eae722         Elf                 Sage  2018-07-26T06:57:07Z
# 667   b875b2         Elf              Acolyte  2018-08-26T21:41:51Z
# 671   26ad32       Gnome    Mercenary Veteran  2018-07-07T21:03:04Z
# 764   95d4a1       Human   Cloistered Scholar  2018-09-07T09:41:42Z
# 802   3c799c  Dragonborn               Knight  2018-07-30T16:58:18Z
# 826   68d2de         Elf   Cloistered Scholar  2018-08-06T04:07:09Z
# 845   3c6e8b       Kenku            Charlatan  2018-05-27T21:43:53Z
# 918   a18c47    Halfling   Cloistered Scholar  2018-06-13T01:07:13Z
# 939   5b38db       Human            Folk Hero  2018-09-10T00:11:19Z
# 951   f47e60       Dwarf   Cloistered Scholar  2018-07-28T16:09:12Z
# 957   934936       Gnome                 Sage  2018-08-25T20:18:30Z
# 961   d61656       Human               Custom  2018-06-18T10:53:15Z
# 1045  5e4bdd       Dwarf          Haunted One  2018-04-16T21:33:57Z
# 1132  84085a       Human            Outlander  2018-05-01T18:33:57Z
# 1170  4994c4         Elf          Haunted One  2018-04-27T22:31:59Z
# 1193  7b77dd       Gnome                Noble  2018-04-21T13:32:03Z
# 1248  c77d90         Elf          Haunted One  2018-04-18T04:12:24Z
# 1303  9ba8c2    Halfling                 Nerd  2018-05-16T00:22:13Z
# 1307  30b9a2     Firbolg                 Nerd  2018-05-16T00:19:41Z
# 1322  cfaf95         Elf             Courtier  2018-05-12T17:18:52Z
# 1329  17c920       Human             Inventor  2018-05-09T19:25:18Z
#
#                            class            justClass  \
# 3                       Wizard 1               Wizard
# 122                     Wizard 6               Wizard
# 148                     Wizard 4               Wizard
# 154           Paladin 4|Wizard 2       Paladin|Wizard
# 193                    Wizard 10               Wizard
# 292           Cleric 1|Wizard 13        Cleric|Wizard
# 340                     Wizard 1               Wizard
# 361                     Wizard 5               Wizard
# 388                     Wizard 7               Wizard
# 394                     Wizard 3               Wizard
# 415                    Wizard 20               Wizard
# 419                     Wizard 4               Wizard
# 432                     Wizard 3               Wizard
# 479             Rogue 3|Wizard 2         Rogue|Wizard
# 529                     Wizard 2               Wizard
# 539                     Wizard 4               Wizard
# 548                     Wizard 3               Wizard
# 552                     Wizard 3               Wizard
# 560                    Wizard 12               Wizard
# 580                     Wizard 1               Wizard
# 616                     Wizard 4               Wizard
# 627                     Wizard 1               Wizard
# 631                     Wizard 3               Wizard
# 633                     Wizard 4               Wizard
# 640                     Wizard 1               Wizard
# 652                    Wizard 16               Wizard
# 657                     Wizard 5               Wizard
# 663           Fighter 5|Wizard 1       Fighter|Wizard
# 664           Wizard 5|Fighter 1       Wizard|Fighter
# 667          Wizard 12|Fighter 1       Wizard|Fighter
# 671                     Wizard 8               Wizard
# 764                     Wizard 2               Wizard
# 802          Paladin 2|Wizard 11       Paladin|Wizard
# 826                     Wizard 1               Wizard
# 845                     Wizard 1               Wizard
# 918                    Wizard 16               Wizard
# 939           Wizard 5|Warlock 2       Wizard|Warlock
# 951                     Wizard 1               Wizard
# 957                     Wizard 4               Wizard
# 961              Monk 1|Wizard 3          Monk|Wizard
# 1045                    Wizard 1               Wizard
# 1132                   Wizard 14               Wizard
# 1170                    Wizard 1               Wizard
# 1193                    Wizard 1               Wizard
# 1248                    Wizard 1               Wizard
# 1303                    Wizard 4               Wizard
# 1307                    Wizard 4               Wizard
# 1322  Wizard 10|Cleric 1|Druid 1  Wizard|Cleric|Druid
# 1329                    Wizard 3               Wizard
#
#                                  subclass  level  \
# 3                                     NaN      1
# 122                 School of Enchantment      6
# 148                  School of Necromancy      4
# 154            Oath of Conquest|War Magic      6
# 193                  School of Necromancy     10
# 292     Light Domain|School of Divination     14
# 340                                   NaN      1
# 361                   School of Evocation      5
# 388                    School of Illusion      7
# 394                 School of Conjuration      3
# 415                 School of Conjuration     20
# 419                   School of Evocation      4
# 432                  School of Abjuration      3
# 479   Arcane Trickster|School of Illusion      5
# 529                  School of Abjuration      2
# 539                          Lore Mastery      4
# 548                   School of Evocation      3
# 552                    School of Illusion      3
# 560                   School of Evocation     12
# 580                                   NaN      1
# 616                   School of Evocation      4
# 627                                   NaN      1
# 631                   School of Evocation      3
# 633                  School of Abjuration      4
# 640                                   NaN      1
# 652                 School of Conjuration     16
# 657                  School of Divination      5
# 663                      Eldritch Knight|      6
# 664                  School of Evocation|      6
# 667                 School of Necromancy|     13
# 671                   School of Evocation      8
# 764                          Lore Mastery      2
# 802                |School of Conjuration     13
# 826                                   NaN      1
# 845                                   NaN      1
# 918                  School of Necromancy     16
# 939      School of Abjuration|The Archfey      7
# 951                                   NaN      1
# 957                    School of Illusion      4
# 961                         |Bladesinging      4
# 1045                                  NaN      1
# 1132                 School of Abjuration     14
# 1170                                  NaN      1
# 1193                                  NaN      1
# 1248                                  NaN      1
# 1303                 School of Abjuration      4
# 1307                  School of Evocation      4
# 1322             Bladesinging|War Domain|     12
# 1329              School of Transmutation      3
#
#                                                   feats   HP  ...  \
# 3                                                   NaN    7  ...
# 122                                                 NaN   42  ...
# 148                                                 NaN   24  ...
# 154                                          War Caster   58  ...
# 193                                                 NaN   62  ...
# 292                                               Lucky  102  ...
# 340                                                 NaN    9  ...
# 361                                                 NaN   26  ...
# 388                                                 NaN   42  ...
# 394                                                 NaN   24  ...
# 415   Spell Sniper|Elven Accuracy|Elemental Adept|Wa...  122  ...
# 419                                                 NaN   30  ...
# 432                                                 NaN   17  ...
# 479                                                 NaN   31  ...
# 529                                                 NaN   14  ...
# 539                                                 NaN   30  ...
# 548                                                 NaN   16  ...
# 552                                             Prodigy   11  ...
# 560                                                 NaN  100  ...
# 580                                                 NaN   10  ...
# 616                                                 NaN   25  ...
# 627                                                 NaN    7  ...
# 631                                                 NaN   21  ...
# 633                                                 NaN   22  ...
# 640                                                 NaN    8  ...
# 652                              Inspiring Leader|Tough  130  ...
# 657                                                 NaN   30  ...
# 663                                              Healer   69  ...
# 664                                               Tough   54  ...
# 667                                                 NaN   82  ...
# 671                                                 NaN   66  ...
# 764                                            Linguist   16  ...
# 802                                                 NaN   72  ...
# 826                                                 NaN    7  ...
# 845                                                 NaN    6  ...
# 918                            War Caster|Second Chance  144  ...
# 939                                        Spell Sniper   25  ...
# 951                                                 NaN    9  ...
# 957                                                 NaN   32  ...
# 961                                           Resilient   25  ...
# 1045                                                NaN   10  ...
# 1132                                          Observant   58  ...
# 1170                                                NaN    7  ...
# 1193                                                NaN    8  ...
# 1248                                                NaN    8  ...
# 1303                                                NaN   26  ...
# 1307                                              Tough   34  ...
# 1322                                         War Caster   64  ...
# 1329                                         War Caster   24  ...
#
#                                                  skills  \
# 3     Stealth|Arcana|Investigation|Perception|Deception
# 122                Arcana|History|Investigation|Insight
# 148   Sleight of Hand|Stealth|Arcana|Insight|Perception
# 154           Athletics|Insight|Intimidation|Persuasion
# 193                     Arcana|History|Religion|Insight
# 292                 History|Religion|Insight|Persuasion
# 340               Arcana|History|Investigation|Religion
# 361                    Investigation|Insight|Perception
# 388                Arcana|History|Investigation|Insight
# 394          Athletics|Investigation|Insight|Perception
# 415       Arcana|Insight|Medicine|Perception|Persuasion
# 419             Arcana|Animal Handling|Insight|Survival
# 432                  Arcana|Religion|Insight|Perception
# 479   Acrobatics|Sleight of Hand|Stealth|Investigati...
# 529               Arcana|History|Investigation|Religion
# 539     Arcana|History|Investigation|Insight|Perception
# 548               Arcana|Investigation|Religion|Insight
# 552   Arcana|History|Investigation|Perception|Persua...
# 560                    Arcana|Religion|Insight|Medicine
# 580                Arcana|History|Investigation|Insight
# 616                Arcana|History|Investigation|Insight
# 627                     Arcana|History|Insight|Survival
# 631          Arcana|History|Religion|Insight|Perception
# 633                Arcana|History|Investigation|Insight
# 640   Stealth|Arcana|Investigation|Perception|Persua...
# 652      Arcana|History|Insight|Intimidation|Persuasion
# 657                     Arcana|History|Religion|Insight
# 663   Sleight of Hand|Stealth|Insight|Perception|Per...
# 664    Arcana|History|Investigation|Medicine|Perception
# 667          Arcana|History|Religion|Insight|Perception
# 671                 Athletics|Arcana|Insight|Persuasion
# 764               Arcana|History|Investigation|Religion
# 802                  Arcana|Religion|Insight|Persuasion
# 826          Arcana|History|Insight|Medicine|Perception
# 845   Sleight of Hand|Stealth|Arcana|Investigation|D...
# 918               Arcana|History|Investigation|Religion
# 939               Arcana|Investigation|Religion|Insight
# 951                Arcana|History|Investigation|Insight
# 957                Arcana|History|Investigation|Insight
# 961   Acrobatics|Stealth|Arcana|History|Investigatio...
# 1045              Arcana|Investigation|Insight|Medicine
# 1132         Athletics|Arcana|History|Medicine|Survival
# 1170    Arcana|History|Investigation|Insight|Perception
# 1193               Arcana|History|Investigation|Insight
# 1248  History|Investigation|Insight|Perception|Survival
# 1303          Arcana|Investigation|Religion|Performance
# 1307           Arcana|Investigation|Insight|Performance
# 1322  Arcana|History|Insight|Perception|Performance|...
# 1329     Arcana|Investigation|Religion|Insight|Medicine
#
#                                                 weapons  \
# 3                                          Quarterstaff
# 122                                        Quarterstaff
# 148                                        Quarterstaff
# 154         Greatsword|Longsword|Shortsword|Whip|Dagger
# 193                                        Quarterstaff
# 292                                Mace|Crossbow, light
# 340                                              Dagger
# 361                                        Quarterstaff
# 388                                              Dagger
# 394                                              Dagger
# 415                                        Quarterstaff
# 419                                        Quarterstaff
# 432                                              Dagger
# 479                Shortsword|Dagger +2|Crossbow, Light
# 529                                              Dagger
# 539                                 Quarterstaff|Dagger
# 548                                              Dagger
# 552                                        Quarterstaff
# 560                                        Quarterstaff
# 580                                        Quarterstaff
# 616   Fire Bolt|(1)Magic Missle (3x)|(1)Thunderwave|...
# 627                                        Quarterstaff
# 631                                              Dagger
# 633                                              Dagger
# 640                                              Dagger
# 652                                              Dagger
# 657                                        Quarterstaff
# 663                          Longbow|Shortsword|Handaxe
# 664        Quarterstaff|Silvered Dagger|Silvered Rapier
# 667                                        Quarterstaff
# 671                                        Quarterstaff
# 764                                        Quarterstaff
# 802                           Greatsword ro1ro2|Javelin
# 826                                              Dagger
# 845                                              Dagger
# 918                                              Dagger
# 939                              Dagger|Crossbow, Light
# 951                                        Quarterstaff
# 957                                        Quarterstaff
# 961                    Shortsword|Katana|Unarmed strike
# 1045                                       Quarterstaff
# 1132                                       Quarterstaff
# 1170                                             Dagger
# 1193                                             Dagger
# 1248                Quarterstaff|Magic Missle|Fire Bolt
# 1303                                                NaN
# 1307                                       Quarterstaff
# 1322                                       Quarterstaff
# 1329                                       Quarterstaff
#
#                                                  spells       day  \
# 3                                                   NaN  08 04 18
# 122                                                 NaN  08 05 18
# 148                                                 NaN  06 10 18
# 154   Control Flame (wiz)*0|Create Bonfire (wiz)*0|S...  09 08 18
# 193                                      Animate Dead*3  06 01 18
# 292               Light*0|Burning Hands*1|Faerie Fire*1  06 16 18
# 340   Firebolt*0|Shocking Grasp*0|Mage Hand*0|Burnin...  06 16 18
# 361                                                 NaN  06 22 18
# 388                                                 NaN  08 30 18
# 394                                                 NaN  06 27 18
# 415                                                 NaN  07 09 18
# 419                                                 NaN  06 28 18
# 432   Fire Bolt (1d10 120ft)*0|Ray Of Frost (1d8 60f...  07 26 18
# 479   Minor Illusion*0|Friends*0|Mage Hand*0|Dancing...  06 14 18
# 529                                                 NaN  06 08 18
# 539   Message*0|firebolt*0|shape water*0|Mending*0|a...  08 17 18
# 548                                                 NaN  05 26 18
# 552                                                 NaN  05 27 18
# 560                                                 NaN  06 24 18
# 580                                                 NaN  09 04 18
# 616   Fire Bolt*0|Mending/2 lodestones/1min*0|TrueSt...  07 29 18
# 627   Prestidigitation*0|Fire Bolt*0|Minor Illusion*...  05 25 18
# 631                                                 NaN  05 26 18
# 633                                                 NaN  06 15 18
# 640   Fire Bolt*0|Sword Burst*0|Toll The Dead*0|Dete...  07 22 18
# 652   Infestation*0|Mage Hand*0|Friends*0|Message*0|...  06 24 18
# 657                                                 NaN  08 12 18
# 663   Blade Ward - EK*0|Control Flames - Wiz*0|Creat...  07 25 18
# 664   Blade Ward *0|Fire Bolt *0|Frostbite *0|Sword ...  07 25 18
# 667   Light*0|Mage Hand*0|Acid Splash*0|Chill Touch*...  08 26 18
# 671                                                 NaN  07 07 18
# 764                                                 NaN  09 07 18
# 802   Firebolt*0|Prestidigitation*0|Toll The dead *0...  07 30 18
# 826                                                 NaN  08 05 18
# 845   Prestidigitation*0|Fire Bolt*0|Message*0|Color...  05 27 18
# 918                                      Animate Dead*3  06 12 18
# 939   Firebolt*0|Light*0|Dancing Lights*0|Poison Spr...  09 09 18
# 951                                                 NaN  07 28 18
# 957   Minor Illusion*0|Firebolt*0|Mage Hand*0|Frostb...  08 25 18
# 961              Fire Bolt*0|Message*0|Create Bonfire*0  06 18 18
# 1045                                                NaN  04 16 18
# 1132                                                NaN  05 01 18
# 1170                                                NaN  04 27 18
# 1193  Minor Illusion (Gnome)*0|Ray Of Frost*0|Presti...  04 21 18
# 1248  Mage Hand*0|Minor Illusion*0|Firebolt*0|Presti...  04 17 18
# 1303  Friends*0|Create Bonfire*0|Mage Hand*0|Identif...  05 15 18
# 1307  On/Off*0|Light*0|Lightning Lure*0|Shocking Gra...  05 15 18
# 1322                   Divine Favor*1|Shield of Faith*1  05 12 18
# 1329                                                NaN  05 09 18
#
#       processedAlignment  good  lawful processedRace  \
# 3                    NaN   NaN     NaN           Elf
# 122                  NaN   NaN     NaN        Goblin
# 148                  NaN   NaN     NaN           Elf
# 154                   NE     E       N      Tiefling
# 193                  NaN   NaN     NaN         Human
# 292                  NaN   NaN     NaN         Human
# 340                   NG     G       N         Gnome
# 361                  NaN   NaN     NaN        Goblin
# 388                  NaN   NaN     NaN         Human
# 394                  NaN   NaN     NaN           Elf
# 415                  NaN   NaN     NaN           Elf
# 419                  NaN   NaN     NaN         Human
# 432                  NaN   NaN     NaN           Elf
# 479                   NN     N       N         Gnome
# 529                  NaN   NaN     NaN         Gnome
# 539                  NaN   NaN     NaN           Elf
# 548                  NaN   NaN     NaN        Goblin
# 552                  NaN   NaN     NaN         Human
# 560                  NaN   NaN     NaN         Gnome
# 580                  NaN   NaN     NaN         Dwarf
# 616                  NaN   NaN     NaN         Gnome
# 627                  NaN   NaN     NaN         Gnome
# 631                  NaN   NaN     NaN           Elf
# 633                   NN     N       N        Kobold
# 640                   CN     N       C           Elf
# 652                   LE     E       L         Human
# 657                  NaN   NaN     NaN         Gnome
# 663                   CN     N       C      Tiefling
# 664                  NaN   NaN     NaN           Elf
# 667                  NaN   NaN     NaN           Elf
# 671                  NaN   NaN     NaN         Gnome
# 764                  NaN   NaN     NaN         Human
# 802                   LN     N       L    Dragonborn
# 826                  NaN   NaN     NaN           Elf
# 845                   CN     N       C         Kenku
# 918                  NaN   NaN     NaN      Halfling
# 939                   LG     G       L         Human
# 951                  NaN   NaN     NaN         Dwarf
# 957                  NaN   NaN     NaN         Gnome
# 961                  NaN   NaN     NaN         Human
# 1045                 NaN   NaN     NaN         Dwarf
# 1132                  CN     N       C         Human
# 1170                 NaN   NaN     NaN           Elf
# 1193                  LN     N       L         Gnome
# 1248                 NaN   NaN     NaN           Elf
# 1303                 NaN   NaN     NaN      Halfling
# 1307                 NaN   NaN     NaN       Firbolg
# 1322                 NaN   NaN     NaN           Elf
# 1329                  NG     G       N         Human
#
#                                         processedSpells  \
# 3                                                   NaN
# 122                                                 NaN
# 148                                                 NaN
# 154   Create Bonfire*0|Sword Burst*0|Thaumaturgy*0|A...
# 193                                      Animate Dead*3
# 292               Light*0|Burning Hands*1|Faerie Fire*1
# 340   Fire Bolt*0|Shocking Grasp*0|Mage Hand*0|Burni...
# 361                                                 NaN
# 388                                                 NaN
# 394                                                 NaN
# 415                                                 NaN
# 419                                                 NaN
# 432   Fire Bolt*0|Ray of Frost*0|Mage Hand*0|Message...
# 479   Minor Illusion*0|Friends*0|Mage Hand*0|Dancing...
# 529                                                 NaN
# 539   Message*0|Fire Bolt*0|Shape Water*0|Mending*0|...
# 548                                                 NaN
# 552                                                 NaN
# 560                                                 NaN
# 580                                                 NaN
# 616   Fire Bolt*0|True Strike*0|Mage Hand*0|Shield*1...
# 627   Prestidigitation*0|Fire Bolt*0|Minor Illusion*...
# 631                                                 NaN
# 633                                                 NaN
# 640   Fire Bolt*0|Sword Burst*0|Toll the Dead*0|Dete...
# 652   Infestation*0|Mage Hand*0|Friends*0|Message*0|...
# 657                                                 NaN
# 663   Blade Ward*0|Control Flames*0|Create Bonfire*0...
# 664   Blade Ward*0|Fire Bolt*0|Frostbite*0|Sword Bur...
# 667   Light*0|Mage Hand*0|Acid Splash*0|Chill Touch*...
# 671                                                 NaN
# 764                                                 NaN
# 802   Fire Bolt*0|Prestidigitation*0|Toll the Dead*0...
# 826                                                 NaN
# 845   Prestidigitation*0|Fire Bolt*0|Message*0|Color...
# 918                                      Animate Dead*3
# 939   Fire Bolt*0|Light*0|Dancing Lights*0|Poison Sp...
# 951                                                 NaN
# 957   Minor Illusion*0|Fire Bolt*0|Mage Hand*0|Frost...
# 961              Fire Bolt*0|Message*0|Create Bonfire*0
# 1045                                                NaN
# 1132                                                NaN
# 1170                                                NaN
# 1193  Minor Illusion*0|Ray of Frost*0|Prestidigitati...
# 1248  Mage Hand*0|Minor Illusion*0|Fire Bolt*0|Prest...
# 1303  Friends*0|Create Bonfire*0|Mage Hand*0|Identif...
# 1307  Light*0|Lightning Lure*0|Shocking Grasp*0|Colo...
# 1322                   Divine Favor*1|Shield of Faith*1
# 1329                                                NaN
#
#                                  processedWeapons
# 3                                    Quarterstaff
# 122                                  Quarterstaff
# 148                                  Quarterstaff
# 154   Greatsword|Longsword|Shortsword|Whip|Dagger
# 193                                  Quarterstaff
# 292                          Mace|Crossbow, Light
# 340                                        Dagger
# 361                                  Quarterstaff
# 388                                        Dagger
# 394                                        Dagger
# 415                                  Quarterstaff
# 419                                  Quarterstaff
# 432                                        Dagger
# 479             Shortsword|Dagger|Crossbow, Light
# 529                                        Dagger
# 539                           Quarterstaff|Dagger
# 548                                        Dagger
# 552                                  Quarterstaff
# 560                                  Quarterstaff
# 580                                  Quarterstaff
# 616                                           NaN
# 627                                  Quarterstaff
# 631                                        Dagger
# 633                                        Dagger
# 640                                        Dagger
# 652                                        Dagger
# 657                                  Quarterstaff
# 663                    Longbow|Shortsword|Handaxe
# 664                    Quarterstaff|Dagger|Rapier
# 667                                  Quarterstaff
# 671                                  Quarterstaff
# 764                                  Quarterstaff
# 802                            Greatsword|Javelin
# 826                                        Dagger
# 845                                        Dagger
# 918                                        Dagger
# 939                        Dagger|Crossbow, Light
# 951                                  Quarterstaff
# 957                                  Quarterstaff
# 961                     Shortsword|Unarmed Strike
# 1045                                 Quarterstaff
# 1132                                 Quarterstaff
# 1170                                       Dagger
# 1193                                       Dagger
# 1248                                 Quarterstaff
# 1303                                          NaN
# 1307                                 Quarterstaff
# 1322                                 Quarterstaff
# 1329                                 Quarterstaff
#
# [49 rows x 28 columns]
